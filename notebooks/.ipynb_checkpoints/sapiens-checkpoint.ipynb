# %%
import pandas as pd
import os
import gc

from time import sleep

import gspread_dataframe as gs_df

os.chdir("../")

# INITIALIZE DRIVER
from selenium import webdriver
from sapiens import LoginPage, KEYS
import functions


% reload_ext autoreload
% autoreload 2

# %%
driver = webdriver.Firefox()
sapiens = LoginPage(driver).login('33831640807', 'Fer465023@ur_')

# %% [markdown]
# ### Criar o Data Frame para exportar os dados

# %%
df = pd.DataFrame(columns=KEYS)

#planilha = pd.read_excel("files/planilha_obito.xlsx", sheet_name="consulta_RF", dtype=str)

# %%
planilha.columns = ["Nome", "cpf", "fistel", "situação", "estado"]

# %%
planilha = planilha.sort_values(by="Nome")
planilha.head()
# Out:
#                                                    Nome             cpf  \
# 6779                           CARLOS AUGUSTO RODRIGUES     00096537752
# 3308   IFC INTERNATIONAL FOOD COMPANY INDUSTRIA DE A...  02473696000107
# 2970                               .JOSE ANTONIO SOARES     07362475802
# 3427                   11500 EMPREENDIMENTOS LTDA - EPP  04720254000135
# 7092                                    A C A SANTOS-ME  64159692000106
#
#            fistel situação estado
# 6779  80104719923      nan    nan
# 3308  50403232201      nan    nan
# 2970  80100864449      nan    nan
# 3427  50402126742      nan    nan
# 7092  50406300933      nan    nan

# %% [markdown]
# ### Leitura dos Dados Brutos na Planilha

# %%
gc = functions.authenticate_google("files/anatel.json")

sht = gc.open(title='RC')

# %%
registros = sht.worksheet('Registros')
registros_rf = sht.worksheet('Registros_RF')

# %%
#lista_CPF = registros.col_values(1)[1:]

lista_cpf = planilha["cpf"]

# %%
df.tail()
# Out:
# Empty DataFrame
# Columns: [CPF, Nome, Mãe, Data de Nascimento, Sexo, Ano do Óbito, Nacionalidade, Título de Eleitor, Situação Cadastral, Fone, Logradouro, Número, Complemento, Bairro, Cidade, Cep]
# Index: []

# %%
counter = 0

for cpf in lista_cpf:
    
    while len(cpf) < 11:
        
        cpf = '0' + str(cpf)
    
    registro = sapiens.get_registro(cpf)    
   
    if not registro:
    
        if len(cpf) == 11:
            
            sapiens.pesquisa_dados(cpf)
            
            
        else:
            
            sapiens.registros[cpf] = None
            
            
        registro = sapiens.get_registro(cpf)  

            
    
    df = df.append(pd.Series(registro), ignore_index=True)
    
    counter += 1
    
    if counter > 250:
        
        sapiens.close()
        
        del sapiens
        
        print(gc.collect())
        
        sleep(5)
        
        driver = webdriver.Firefox()
        
        sapiens = LoginPage(driver).login('33831640807', 'Fer465023@ur_')
        
        counter = 0
# Out:
# 31166
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-e455cbca5038> in <module>()
#      36         sleep(5)
#      37
# ---> 38         driver = webdriver.Firefox()
#      39
#      40         sapiens = LoginPage(driver).login('33831640807', 'Fer465023@ur_')
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, log_path, firefox_options)
#     156                 command_executor=executor,
#     157                 desired_capabilities=capabilities,
# --> 158                 keep_alive=True)
#     159
#     160         # Selenium remote
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\remote\webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     152             warnings.warn("Please use FirefoxOptions to set browser profile",
#     153                           DeprecationWarning)
# --> 154         self.start_session(desired_capabilities, browser_profile)
#     155         self._switch_to = SwitchTo(self)
#     156         self._mobile = Mobile(self)
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\remote\webdriver.py in start_session(self, capabilities, browser_profile)
#     241         parameters = {"capabilities": w3c_caps,
#     242                       "desiredCapabilities": capabilities}
# --> 243         response = self.execute(Command.NEW_SESSION, parameters)
#     244         if 'sessionId' not in response:
#     245             response = response['value']
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     308
#     309         params = self._wrap_value(params)
# --> 310         response = self.command_executor.execute(driver_command, params)
#     311         if response:
#     312             self.error_handler.check_response(response)
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     464         data = utils.dump_json(params)
#     465         url = '%s%s' % (self._url, path)
# --> 466         return self._request(command_info[0], url, body=data)
#     467
#     468     def _request(self, method, url, body=None):
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     488             try:
#     489                 self._conn.request(method, parsed_url.path, body, headers)
# --> 490                 resp = self._conn.getresponse()
#     491             except (httplib.HTTPException, socket.error):
#     492                 self._conn.close()
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = df.fillna("")

df.head()
# Out:
#   CPF Nome Mãe Data de Nascimento Sexo Ano do Óbito Nacionalidade  \
# 0
# 1
# 2
# 3
# 4
#
#   Título de Eleitor Situação Cadastral Fone Logradouro Número Complemento  \
# 0
# 1
# 2
# 3
# 4
#
#   Bairro Cidade Cep
# 0
# 1
# 2
# 3
# 4

# %%
df.tail()
# Out:
#     CPF Nome Mãe Data de Nascimento Sexo Ano do Óbito Nacionalidade  \
# 505
# 506
# 507
# 508
# 509
#
#     Título de Eleitor Situação Cadastral Fone Logradouro Número Complemento  \
# 505
# 506
# 507
# 508
# 509
#
#     Bairro Cidade Cep
# 505
# 506
# 507
# 508
# 509

# %%
cols = ["Logradouro", "Número", "Complemento", "Bairro", "Cep", "Cidade"]

df["Endereço_Completo"] = df.apply(lambda row: " ".join([str(row["Logradouro"]), 
                                                         str(row["Número"]), 
                                                         str(row["Complemento"]),
                                                         str(row["Bairro"]), "\n", "CEP:", 
                                                         str(row["Cep"]), 
                                                         str(row["Cidade"])]
                                                       ), axis=1
                                  )

# %%
df.to_excel("registros_cadin.csv", index=False)

# %%
gs_df.set_with_dataframe(registros_rf, df, row=142, include_column_header=False)
#gs_df.set_with_dataframe(registros, pd.DataFrame(df["Nome"]), row=2, col=9, include_column_header=False)
#gs_df.set_with_dataframe(registros, pd.DataFrame(df["Endereço_Completo"]), row=2, col=12, include_column_header=False)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-25-7b2d7338a1b3> in <module>()
# ----> 1 gs_df.set_with_dataframe(registros_rf, df, row=142, include_column_header=False)
#       2 #gs_df.set_with_dataframe(registros, pd.DataFrame(df["Nome"]), row=2, col=9, include_column_header=False)
#       3 #gs_df.set_with_dataframe(registros, pd.DataFrame(df["Endereço_Completo"]), row=2, col=12, include_column_header=False)
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\gspread_dataframe.py in set_with_dataframe(worksheet, dataframe, row, col, include_index, include_column_header, resize, allow_formulas)
#     209     logger.debug("%d cell updates to send", len(cells_to_update))
#     210
# --> 211     resp = worksheet.update_cells(cells_to_update, value_input_option='USER_ENTERED')
#     212     logger.debug("Cell update response: %s", resp)
#     213
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\gspread\models.py in update_cells(self, cell_list, value_input_option)
#     607             },
#     608             body={
# --> 609                 'values': values_rect
#     610             }
#     611         )
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\gspread\models.py in values_update(self, range, params, body)
#     113     def values_update(self, range, params=None, body=None):
#     114         url = SPREADSHEET_VALUES_URL % (self.id, quote(range, safe=''))
# --> 115         r = self.client.request('put', url, params=params, json=body)
#     116         return r.json()
#     117
#
# C:\Users\rsilva\miniconda3\envs\automation\lib\site-packages\gspread\client.py in request(self, method, endpoint, params, data, json, files, headers)
#      77             return response
#      78         else:
# ---> 79             raise APIError(response)
#      80
#      81     def list_spreadsheet_files(self):
#
# APIError: {
#   "error": {
#     "code": 401,
#     "message": "Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.",
#     "status": "UNAUTHENTICATED"
#   }
# }

# %%
registros.row_count
# Out:
# 2006
